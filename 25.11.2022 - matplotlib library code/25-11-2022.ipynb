# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.DataFrame({'a' : [[1,2], [4,5]], 'b' : [11, 13]})

# %%
df.explode('a')
# Out:
#    a   b
# 0  1  11
# 0  2  11
# 1  4  13
# 1  5  13

# %%
df2 = pd.DataFrame({'a' : [1,2,3], 'b' : [4, 5, 6]})

def get_sum(df2):
    return df2.assign(sum = df2.a + df2.b)

def get_diff(df2):
    return df2.assign(diff = df2.b - df2.a)

df2 = df2.pipe(get_sum).pipe(get_diff)
df2
# Out:
#    a  b  sum  diff
# 0  1  4    5     3
# 1  2  5    7     3
# 2  3  6    9     3

# %%
plt.style.use('seaborn-darkgrid')

# %%
id1 = np.arange(1,10)
score = np.arange(20, 110, 10)
plt.bar(id1, score)
plt.xlabel('Student ID')
plt.ylabel('Score')
plt.show()

# %%
id1 = np.arange(1,10)
score = np.arange(20, 110, 10)

plt.figure(figsize= (8,5))
ax=plt.axes()
ax.set_facecolor("#EC3FF3")

plt.bar(id1, score, color = '#FFA726')
plt.xlabel('Student ID')
plt.ylabel('Score')
plt.show()

# %%
x1 = [1,3,5,7]
x2 = [2,4,6,8]

y1 = [7,7,7,7]
y2 = [17,18,29,40]

plt.figure(figsize= (8,5))
ax = plt.axes()
ax.set_facecolor('white')
plt.bar(x1, y1, label = 'first', color = '#FF6F00')
plt.bar(x2, y2, label = 'second', color = '#FFB300')

plt.xlabel('Student ID')
plt.ylabel('Score')
plt.show()

# %%
Age = [28, 33, 43, 45, 57]
Name = ['Emre', 'Çağla', 'Fatih', 'Zeynep', 'Ceren']
plt.barh(Name, Age, color='yellowgreen')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
num1 = np.array([1,3,5,7,9])
num2 = np.array([2,4,6,8,10])

plt.figure(figsize=(8,4))
plt.bar(num1, num1**2, width=0.2, color='#FF6F00')
plt.bar(num2, num2**2, width=0.2, color = '#FFB300')

plt.show()

# %%
num1 = np.array([1,3,5,7,9])
num2 = np.array([2,4,6,8,10])

plt.figure(figsize=(8,4))
plt.bar(num1, num1**2, width=0.2, color='#FF6F00')
plt.bar(num2, num2**2, width=0.2, color = '#FFB300')

for x, y in zip(num1, num1**2):#iki paremetreyi taşıyor
    plt.text(x,y + 0.05, '%d' % y, ha = 'center', va = 'bottom')#horizontal,v aliment

for x,y in zip(num2, num2**2):
    plt.text(x,y+0.05, '%d' % y, ha = 'center', va = 'bottom')
plt.show()

# %%
x = np.arange(1,21)
plt.figure(figsize = (16,8))
y1 = np.random.uniform(0.1, 0.7, 20)
y2 = np.random.uniform(0.1, 0.7, 20)

plt.bar(x, +y1, facecolor = '#C0CA33', edgecolor = 'white')
plt.bar(x, -y2, facecolor = '#FF9800', edgecolor = 'white')

for x, y in zip(x, y1):
    plt.text(x,y + 0.05, '%.2f' % y, ha = 'center', va = 'bottom')
    
plt.xlim(0, 21)
plt.ylim(-1.25, +1.25)
plt.show()

# %%
#üst üste bindirilmiş dikey çubuk grafik (stack vertical bar)

# %%
x1 = ['Gözde', 'Buse', 'Alp', 'Süleyman']
y1 = [17, 18, 29, 40]
y2 = [20, 21, 22, 23]

plt.figure(figsize= (5,7))

plt.bar(x1, y1, label = 'Satışa açık biletler', width=0.5, color = '#FF6F00')
plt.bar(x1, y2, label = 'Satışa kapalı biletler', bottom = y1 ,width=0.5, color = '#FFB300')

plt.xlabel('x')
plt.ylabel('Y')
plt.legend() #çubukların labellarını yazdırıyor
plt.show()

# %%
x1 = ['Gözde', 'Buse', 'Alp', 'Süleyman']
y1 = np.array([17, 18, 29, 40])
y2 = np.array([20, 21, 22, 23])
y3 = np.array([5, 9, 11, 12])
plt.figure(figsize= (5,7))

plt.bar(x1, y1, label = 'Satışa açık biletler', width=0.5, color = '#FF6F00')
plt.bar(x1, y2, label = 'Satışa kapalı biletler', bottom = y1 ,width=0.5, color = '#FFB300')
plt.bar(x1, y3, label = 'İptal olan biletler', bottom = y1+y2 ,width=0.5, color = '#F7DC6F')

plt.xlabel('x')
plt.ylabel('Y')
plt.legend() #çubukların labellarını yazdırıyor
plt.show()

# %%
plt.style.use("seaborn-darkgrid")
x1 = ["Gözde","Buse","Alp","Süleyman"]
y1 = [17,18,29,40]
y2 = [20,21,22,23]

plt.figure(figsize=(8,7))

plt.barh(x1,y1, label="Satışa Açık Biletler", height=0.5, color="#FF6F00")
plt.barh(x1,y2, label="Satışa Kapalı Biletler", height=0.5, left=y1, color="#FFB300")

plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
x1 = ["Gözde","Buse","Alp","Süleyman"]
y1 = [17,18,29,40]
y2 = [20,21,22,23]

plt.figure(figsize=(8,7))

plt.bar(x1,y1, label="Satışa Açık Biletler", width=0.5, color="#FF6F00")
plt.bar(x1,y2, label="Satışa Kapalı Biletler", width=0.5, bottom=y1, color="#FFB300")

plt.xlabel("X")
plt.ylabel("Y")

for x , y in zip(x1,y1):
    plt.text(x, y - 10,'%d' % y, ha = 'center', va = 'bottom')
    
for x , y , z in zip(x1,y2,y1):
    plt.text(x, y+z-10 ,'%d' % y, ha = 'center', va = 'bottom')

plt.legend()
plt.show()

# %%
#Saçılım grafikleri (Scatter Plots-Graphs)

# %%
x1 = np.array([250, 150, 350, 252, 450, 550,455, 358,158,355])
y1 = np.array([40,50,80,90, 100, 50, 60, 88, 54, 45])

plt.scatter(x1, y1)
plt.xlabel('Harcanan zaman', fontsize=12)
plt.ylabel('Skor', fontsize=12)
plt.title('Scatter Graph')

plt.show()

# %%
x2 = np.array([200, 100, 300, 220, 400, 500, 450, 380, 180, 350])
y2=np.array([400, 500, 800, 900, 1000, 250, 310, 390, 570,350])

plt.scatter(x2, y2,color='red')
plt.xlabel('Harcanan zaman', fontsize=12)
plt.ylabel('Skor', fontsize=12)
plt.title('Scatter Graph')

plt.show()

# %%
plt.scatter(x1,y1, label='Class 1',color='m')
plt.scatter(x2, y2, label='Class 2', color='r')
plt.xlabel('Hacanan zaman', fontsize=12)
plt.title('Scatter Graph')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
x = np.random.normal(0, 10, 1000)
y = np.random.normal(0, 10, 1000)

plt.scatter(x,y)

plt.show()

# %%
plt.figure(figsize=(8,6))
x = np.random.random(10)#0 ve 1 arasında 10 sayı getiriyor ilk parametrelerin defaultu 0 ve 1
y = np.random.random(10)

plt.scatter(x, y, c='r', s=50, alpha=0.4, label='One')

plt.legend(bbox_to_anchor = (1.0, 1.0), shadow = True, fontsize = 'x-large')
plt.show()

# %%
plt.figure(figsize=(8,6))
x = np.random.random(10)#0 ve 1 arasında 10 sayı getiriyor ilk parametrelerin defaultu 0 ve 1
y = np.random.random(10)

plt.scatter(np.random.random(10), np.random.random(10), c='r', s=50, alpha=0.4, label='One')
plt.scatter(np.random.random(10), np.random.random(10), c='b', s=100, alpha=0.4, label='Two')
plt.scatter(np.random.random(10), np.random.random(10), c='g', s=150, alpha=0.4, label='Three')
plt.scatter(np.random.random(10), np.random.random(10), c='y', s=200, alpha=0.4, label='Four')

plt.legend(bbox_to_anchor = (1.0, 1.0), shadow = True, fontsize = 'x-large')
plt.show()

# %%
import matplotlib as mpl 
mpl.rcParams.update(mpl.rcParamsDefault)
# %matplotlib inline
plt.style.use('seaborn-darkgrid')

# %%
#Pasta Grafikleri (Pie Charts)

# %%
plt.figure(figsize=(9,9))
area = [48, 30, 20, 15]
labels = ['Low', 'Medium', 'High', 'Critical']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']
plt.pie(area, labels=labels,colors=colors,startangle=45)

plt.show()

# %%
plt.figure(figsize=(9,9))
area = [48, 30, 20, 15]
labels = ['Low', 'Medium', 'High', 'Critical']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']
plt.pie(area, labels=labels,colors=colors,startangle=45, shadow=True, autopct='%1.1f%%')

plt.show()

# %%
plt.figure(figsize=(8,8))
area = [48, 30, 20, 15]

total = np.sum(area)

labels = ['Low', 'Medium', 'High', 'Critical']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']

def val_per(x):
    return '{:.2f}%\n({:.0f})'.format(x, total*x/100)

plt.pie(area, labels=labels,colors=colors,startangle=45, shadow=True, autopct=val_per)
plt.show()

# %%
plt.figure(figsize=(9,9))
area = [48, 30, 20, 15]
labels = ['Low', 'Medium', 'High', 'Critical']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']
plt.pie(area, labels=labels,colors=colors,startangle=45, shadow=True, autopct='%1.1f%%', explode=[0, 0, 0, 0.1])
plt.show()

# %%
plt.figure(figsize=(9,9))
area = [48, 30, 20, 15]
labels = ['Low', 'Medium', 'High', 'Critical']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']
plt.pie(area, labels=labels,colors=colors,startangle=45, shadow=True, autopct='%1.1f%%', explode=[0, 0, 0.1, 0.1])
plt.show()

# %%
plt.figure(figsize=(9,9))
area = [48, 30, 20, 15]
labels = ['Low', 'Medium', 'High', 'Critical']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']
plt.pie(area, labels=labels,colors=colors,startangle=45, shadow=True, autopct='%1.1f%%', explode=[0, 0.1, 0, 0.1])

plt.legend()
plt.show()

# %%
#Donut plot
plt.figure(figsize=(9,9))
area = [48, 30, 20, 15]
labels = ['Low', 'Medium', 'High', 'Critical']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']
plt.pie(area, labels=labels,colors=colors,startangle=45)

my_circle = plt.Circle((0,0),0.7,color='white')#beyaz daire yaptık

p = plt.gcf()#donut yapma
p.gca().add_artist(my_circle)

plt.legend()
plt.show()

# %%
#dairenin içine bir pasta ekle

# %%
plt.figure(figsize=(9,9))
fig.patch.set_facecolor('#DADADA')

area = [48, 30, 20, 15]
labels = ['Low', 'Medium', 'High', 'Critical']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']
plt.pie(area, labels=labels,colors=colors,startangle=45)

my_circle = plt.Circle((0,0),0.7,color='white')#beyaz daire yaptık

p = plt.gcf()#donut yapma
p.gca().add_artist(my_circle)

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [125], line 3
#       1 #Donut plot
#       2 plt.figure(figsize=(9,9))
# ----> 3 plt.fig.patch.set_facecolor('#DADADA')
#       5 area = [48, 30, 20, 15]
#       6 labels = ['Low', 'Medium', 'High', 'Critical']
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'fig'

# %%
plt.figure(figsize=(9,9))
area = [48, 30, 20, 15]
labels = ['Low', 'Medium', 'High', 'Critical']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']
plt.pie(area, labels=labels,colors=colors,startangle=45,explode=[0.03,0.03,0.03,0.03])

my_circle = plt.Circle((0,0),0.7,color='white')#beyaz daire yaptık

p = plt.gcf()#donut yapma
p.gca().add_artist(my_circle)

plt.legend()
plt.show()

# %%
plt.figure(figsize=(9,9))
area = [48, 30, 20, 15]
labels = ['Low', 'Medium', 'High', 'Critical']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']
plt.pie(area, labels=labels,colors=colors,startangle=45,autopct='%1.1f%%',pctdistance=0.85)

my_circle = plt.Circle((0,0),0.7,color='white')#beyaz daire yaptık

p = plt.gcf()#donut yapma
p.gca().add_artist(my_circle)

plt.legend()
plt.show()

# %%
plt.figure(figsize=(9,9))
area = [48, 30, 20, 15]

total = np.sum(area)

def val_per(x):
    return '{:.2f}%\n({:.0f})'.format(x, total*x/100)

labels = ['Low', 'Medium', 'High', 'Critical']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']
plt.pie(area, labels=labels,colors=colors,startangle=45,autopct=val_per,pctdistance=0.85)

my_circle = plt.Circle((0,0),0.7,color='white')#beyaz daire yaptık

p = plt.gcf()#donut yapma
p.gca().add_artist(my_circle)

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
area = [48, 30, 20, 15]
priority = ['Low', 'Medium', 'High', 'Critical']
status = ['Resolved', 'Cancelled', 'Pending', 'Assigned']
company = ['TOGG', 'Tesla', 'Mercedes', 'Audi']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']

plt.subplot(1,3,1)
plt.pie(area, labels=priority, colors=colors, startangle=45)
my_circle = plt.Circle((0,0), 0.7, color = 'white')
p = plt.gcf()
p.gca().add_artist(my_circle)

plt.subplot(1,3,2)
plt.pie(area, labels=status, colors=colors, startangle=45)
my_circle = plt.Circle((0,0), 0.7, color = 'white')
p = plt.gcf()
p.gca().add_artist(my_circle)

plt.subplot(1,3,3)
plt.pie(area, labels=company, colors=colors, startangle=45)
my_circle = plt.Circle((0,0), 0.7, color = 'white')
p = plt.gcf()
p.gca().add_artist(my_circle)

plt.show()

# %%
#Histogram

# %%
x = np.random.normal(0, 1, 2000)
plt.hist(x, bins = 30, color = 'yellowgreen')
plt.gca().set(title = 'Histogram', ylabel = 'Frekans')

plt.show()

# %%
x = np.random.rand(2000)
plt.hist(x, bins = 30, color = '#D4AC0D')
plt.gca().set(title = 'Histogram', ylabel = 'Frekans')
plt.show()

# %%
#comulative distrubution
